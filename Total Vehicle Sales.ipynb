# %%
import pandas as pd
import matplotlib.pyplot as plt


# Output CSV File
#output_data_file = "output_data.csv"

# %%
def bar_graph(csvpath = '', 
              setIndex =  '', 
              plotKind = '' , 
              saveFigure = '', 
              ylabel = '',   
              title = '',
              color = ''):
    
    df = pd.read_csv(f"{csvpath}")

    df.set_index(setIndex, inplace=True)
    df.plot(kind=plotKind, figsize=(20,10), color=color)

    plt.ylabel(ylabel, fontweight="bold", fontsize = 20)
    plt.xlabel("")
    plt.xticks(rotation=90, fontsize=15, fontweight="bold")
    plt.title(title, fontweight="bold", fontsize=20)
    plt.legend(fontsize=15)

    plt.savefig(saveFigure)

    plt.show()

# %%
bar_graph('C:/Users/tj_da/OneDrive/Desktop/Impact_Vehicule_COVID-19/project1data/total_vehicle_sales.csv',
         'observation_date',
          'bar',
          'total_vehicle_sales.png',
          'Total Vehicles Sold (Millions)',
          'Total Vehicles Sold 2020-2022',
          '#069AF3'
         )

# %%
bar_graph('C:/Users/tj_da/OneDrive/Desktop/Impact_Vehicule_COVID-19/project1data/total_vehicle_sales_in_dollars.csv',
          'observation_date',
          'bar',
          'total_sales_rev.png',
          'Dollars (Millions)',
          'Total Sales Revenue 2020 - 2022',
          'mediumseagreen'
         )

# %%
bar_graph('C:/Users/tj_da/OneDrive/Desktop/Impact_Vehicule_COVID-19/project1data/consumer_price_index.csv',
          'observation_date',
          'bar',
          'consumer_price_index.png',
          'Index Value',
          'Consumer Price Index 2020 - 2022',
          'coral'
         )

# %% [markdown]
# # What does the Consumer Price Index measure?

# %%
bar_graph('C:/Users/tj_da/OneDrive/Desktop/Impact_Vehicule_COVID-19/project1data/auto_inventories.csv',
          'observation_date',
          'bar',
          'dealer_inventories.png',
          'Inventory Available',
          'Dealer Inventories 2020 - 2022',
          'blue'                 
          )
