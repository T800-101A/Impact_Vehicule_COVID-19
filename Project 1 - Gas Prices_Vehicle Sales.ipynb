# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as sp

# %%
gas_prices_df = pd. read_csv("/Users/stephanieroethlisberger/Desktop/GAS_PRICES_C19.csv")
total_sales_df = pd. read_csv("/Users/stephanieroethlisberger/Desktop/Total_Vehicle_Sales_Volume.csv")

# %%
df_2020_2023 = gas_prices_df.iloc[236:272]
df_2020_2023 = df_2020_2023.set_index('Date')

df_2020_2023.to_csv("Gas.csv")

# %%
df_2020_2023.head()
# Out:
#         Prices_TX
# Date
# 20-Jan      2.292
# 20-Feb      2.161
# 20-Mar      2.008
# 20-Apr      1.595
# 20-May      1.562

# %%
total_sales_df = pd. read_csv("/Users/stephanieroethlisberger/Desktop/Total_Vehicle_Sales_Volume.csv")

# %%
df_total_sales = total_sales_df.loc[0:36]

# %%
def bar_graph(csvpath = '', 
              setIndex =  '', 
              plotKind = '' , 
              saveFigure = '', 
              ylabel = '',   
              title = '',
              color = ''):
    
    df = pd.read_csv(f"{csvpath}")

    df.set_index(setIndex, inplace=True)
    df.plot(kind=plotKind, figsize=(20,10), color=color)

    plt.ylabel(ylabel, fontweight="bold", fontsize = 20)
    plt.xlabel("")
    plt.xticks(rotation=90, fontsize=15, fontweight="bold")
    plt.title(title, fontweight="bold", fontsize=20)
    plt.legend(fontsize=15)

    plt.savefig(saveFigure)

    plt.show()

# %%
bar_graph("/Users/stephanieroethlisberger/Desktop/Total_Vehicle_Sales_Volume.csv",
          "observation_date",
          "bar",
          "VehicleSales.png",
          'Vehicle Sales in Millions',
          'Total Vehicle Sales 2020-2023',
          '#069AF3'
         )

def bar_graph(csvpath = '', 
              setIndex =  '', 
              plotKind = '' , 
              saveFigure = '', 
              ylabel = '',   
              title = '',
              color = ''):
    
    df = pd.read_csv(f"{csvpath}")

    df.set_index(setIndex, inplace=True)
    df.plot(kind=plotKind, figsize=(20,10), color=color)

    plt.ylabel(ylabel, fontweight="bold", fontsize = 20)
    plt.xlabel("")
    plt.xticks(rotation=90, fontsize=15, fontweight="bold")
    plt.title(title, fontweight="bold", fontsize=20)
    plt.legend(fontsize=15)

    plt.savefig(saveFigure)

    plt.show()

# %%
pd.read_csv(f"/Users/stephanieroethlisberger/Desktop/Gas.csv")
# Out:
#     Unnamed: 0    Date  Prices_TX
# 0          236  20-Jan      2.292
# 1          237  20-Feb      2.161
# 2          238  20-Mar      2.008
# 3          239  20-Apr      1.595
# 4          240  20-May      1.562
# 5          241  20-Jun      1.804
# 6          242  20-Jul      1.933
# 7          243  20-Aug      1.918
# 8          244  20-Sep      1.912
# 9          245  20-Oct      1.878
# 10         246  20-Nov      1.814
# 11         247  20-Dec      1.932
# 12         248  21-Jan      2.085
# 13         249  21-Feb      2.259
# 14         250  21-Mar      2.585
# 15         251  21-Apr      2.605
# 16         252  21-May      2.740
# 17         253  21-Jun      2.785
# 18         254  21-Jul      2.861
# 19         255  21-Aug      2.867
# 20         256  21-Sep      2.859
# 21         257  21-Oct      2.976
# 22         258  21-Nov      3.073
# 23         259  21-Dec      2.967
# 24         260  22-Jan      3.005
# 25         261  22-Feb      3.253
# ...

# %%
pd.read_csv(f"/Users/stephanieroethlisberger/Desktop/GAS_PRICES_C19.csv")
# Out:
#        Date  Prices_TX
# 0    May-00        NaN
# 1    Jun-00      1.540
# 2    Jul-00      1.549
# 3    Aug-00      1.460
# 4    Sep-00      1.491
# ..      ...        ...
# 274  23-Mar      3.097
# 275  23-Apr      3.335
# 276  23-May      3.139
# 277  23-Jun      3.201
# 278  23-Jul      3.312
#
# [279 rows x 2 columns]

# %%
bar_graph("/Users/stephanieroethlisberger/Desktop/Gas.csv",
          "Date",
          "bar",
          "GAS_PRICES_C19.png",
          'Prices_TX',
          'Gas Prices in TX 2020-2023',
          '#069AF3'
         )
